# %% [markdown]
# # SECTION 2: CNN-LSTM MODEL TRAINING

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Reshape, LSTM, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam, SGD, Adamax, RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf

# ========== SETUP ==========
SAMPLE_RATE = 22050
BATCH_SIZE = 32
NUM_CLASSES = 5

# ========== LOAD & PREPARE DATA ==========
X = np.load("X_hybrid_balanced.npy")
y = np.load("y_hybrid_balanced.npy")

X = X / np.max(X)
X = X[..., np.newaxis]
y_cat = to_categorical(y, num_classes=NUM_CLASSES)
class_names = ["belly pain", "burping", "discomfort", "hungry", "tired"]

# Function to allow split tuning
def split_data(split_ratio=(0.8, 0.1, 0.1)):
    X_temp, X_test, y_temp, y_test = train_test_split(X, y_cat, test_size=split_ratio[2], stratify=y, random_state=42)
    val_fraction = split_ratio[1] / (split_ratio[0] + split_ratio[1])
    X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=val_fraction, stratify=y_temp.argmax(1), random_state=42)
    return X_train, X_val, X_test, y_train, y_val, y_test

# ========== ATTENTION LAYER ==========
class AttentionLayer(tf.keras.layers.Layer):
    def __init__(self):
        super(AttentionLayer, self).__init__()

    def build(self, input_shape):
        self.W = self.add_weight(name="att_weight", shape=(input_shape[-1], 1), initializer="normal")
        self.b = self.add_weight(name="att_bias", shape=(input_shape[1], 1), initializer="zeros")
        super().build(input_shape)

    def call(self, x):
        e = tf.keras.backend.tanh(tf.keras.backend.dot(x, self.W) + self.b)
        a = tf.keras.backend.softmax(e, axis=1)
        output = x * a
        return tf.keras.backend.sum(output, axis=1)

# ========== MODEL ==========
def build_cnn_lstm_attention(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.3)(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.3)(x)
    x = Reshape((x.shape[1], x.shape[2] * x.shape[3]))(x)
    x = LSTM(128, return_sequences=True)(x)
    x = Dropout(0.3)(x)
    x = AttentionLayer()(x)
    output = Dense(num_classes, activation='softmax')(x)
    return Model(inputs, output)

# ========== UNIVERSAL RUNNER FUNCTION ==========
def run_cnn_lstm_attention(optimizer_name="Adam", lr=0.001, epochs=60, patience=5, batch_size=16, split_ratio=(0.8, 0.1, 0.1), model_save_path="best_model1.keras"):
    X_train, X_val, X_test, y_train, y_val, y_test = split_data(split_ratio=split_ratio)
    
    model = build_cnn_lstm_attention(X_train.shape[1:], num_classes=NUM_CLASSES)

    if optimizer_name == "Adam":
        optimizer = Adam(learning_rate=lr)
    elif optimizer_name == "SGD":
        optimizer = SGD(learning_rate=lr)
    elif optimizer_name == "RMSprop":
        optimizer = RMSprop(learning_rate=lr)
    elif optimizer_name == "Adamax":
        optimizer = Adamax(learning_rate=lr)
    else:
        raise ValueError(f"Unsupported optimizer: {optimizer_name}")

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    checkpoint = ModelCheckpoint(model_save_path, monitor='val_accuracy', save_best_only=True, verbose=1)
    early_stop = EarlyStopping(monitor='val_accuracy', patience=patience, restore_best_weights=True)

    history = model.fit(X_train, y_train, validation_data=(X_val, y_val),
                        epochs=epochs, batch_size=batch_size,
                        callbacks=[early_stop, checkpoint], verbose=1)

    # Load best model from file
    best_model1 = tf.keras.models.load_model(model_save_path, custom_objects={"AttentionLayer": AttentionLayer})

    train_loss, train_acc = best_model1.evaluate(X_train, y_train, verbose=0)
    val_loss, val_acc = best_model1.evaluate(X_val, y_val, verbose=0)
    test_loss, test_acc = best_model1.evaluate(X_test, y_test, verbose=0)

    print(f"\n🧪 Final Training Accuracy: {train_acc * 100:.2f}%")
    print(f"🧪 Final Validation Accuracy: {val_acc * 100:.2f}%")
    print(f"✅ Final Test Accuracy: {test_acc * 100:.2f}%")

    y_pred = best_model1.predict(X_test).argmax(axis=1)
    y_true = y_test.argmax(axis=1)

    print("\n📊 Classification Report:")
    print(classification_report(y_true, y_pred, target_names=class_names))

    cm = confusion_matrix(y_true, y_pred)
    ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names).plot(cmap='Blues')
    plt.title("Confusion Matrix")
    plt.grid(False)
    plt.show()

    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Training vs Validation Accuracy')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training vs Validation Loss')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    return train_acc, val_acc, test_acc

# %%
print("\n==========================")
print("🔬 Running: CNN-LSTM | RMSprop | 0.001 | 60 Epochs | Split 80:10:10")
print("==========================")
run_cnn_lstm_attention(
    optimizer_name="RMSprop",
    lr=0.001,
    epochs=60,
    batch_size=32,
    patience=10,
    split_ratio=(0.8, 0.10, 0.10)
)

# %%
print("\n==========================")
print("🔬 Running: CNN-LSTM | Adam | 0.001 | 20 Epochs | Split 80:10:10")
print("==========================")
run_cnn_lstm_attention(
    optimizer_name="Adam",
    lr=0.001,
    epochs=20,
    batch_size=32,
    patience=10,
    split_ratio=(0.8, 0.10, 0.10)
)

# %%
print("\n==========================")
print("🔬 Running: CNN-LSTM | Adam | 0.001 | 60 Epochs | Split 80:10:10")
print("==========================")
run_cnn_lstm_attention(
    optimizer_name="Adam",
    lr=0.001,
    epochs=60,
    batch_size=32,
    patience=10,
    split_ratio=(0.8, 0.10, 0.10)
)

# %%
print("\n==========================")
print("🔬 Running: CNN-LSTM | RMSprop | 0.001 | 60 Epochs | Split 80:10:10")
print("==========================")
run_cnn_lstm_attention(
    optimizer_name="RMSprop",
    lr=0.001,
    epochs=60,
    batch_size=32,
    patience=10,
    split_ratio=(0.8, 0.10, 0.10)
)

# %%
print("\n==========================")
print("🔬 Running: CNN-LSTM | RMSprop | 0.001 | 60 Epochs | Split 80:10:10")
print("==========================")
run_cnn_lstm_attention(
    optimizer_name="RMSprop",
    lr=0.001,
    epochs=60,
    batch_size=32,
    patience=10,
    split_ratio=(0.8, 0.10, 0.10)
)

# %%
print("\n==========================")
print("🔬 Running: CNN-LSTM | RMSprop | 0.001 | 60 Epochs | Split 80:10:10")
print("==========================")
run_cnn_lstm_attention(
    optimizer_name="RMSprop",
    lr=0.001,
    epochs=60,
    batch_size=32,
    patience=10,
    split_ratio=(0.8, 0.10, 0.10)
)

# %%
run_cnn_lstm_attention(
    optimizer_name="Adam",
    lr=0.001,
    epochs=60,
    patience=5,
    batch_size=16,
    split_ratio=(0.8, 0.1, 0.1),
    model_save_path="best_model1.keras"
)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Reshape, LSTM, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam, SGD, Adamax, RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf

# ========== SETUP ==========
SAMPLE_RATE = 22050
BATCH_SIZE = 32
NUM_CLASSES = 5

# ========== LOAD & PREPARE DATA ==========
X = np.load("X_hybrid_balanced.npy")
y = np.load("y_hybrid_balanced.npy")

X = X / np.max(X)
X = X[..., np.newaxis]
y_cat = to_categorical(y, num_classes=NUM_CLASSES)
class_names = ["belly pain", "burping", "discomfort", "hungry", "tired"]

# Function to allow split tuning
def split_data(split_ratio=(0.8, 0.1, 0.1)):
    X_temp, X_test, y_temp, y_test = train_test_split(X, y_cat, test_size=split_ratio[2], stratify=y, random_state=42)
    val_fraction = split_ratio[1] / (split_ratio[0] + split_ratio[1])
    X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=val_fraction, stratify=y_temp.argmax(1), random_state=42)
    return X_train, X_val, X_test, y_train, y_val, y_test

# ========== ATTENTION LAYER ==========
class AttentionLayer(tf.keras.layers.Layer):
    def __init__(self):
        super(AttentionLayer, self).__init__()

    def build(self, input_shape):
        self.W = self.add_weight(name="att_weight", shape=(input_shape[-1], 1), initializer="normal")
        self.b = self.add_weight(name="att_bias", shape=(input_shape[1], 1), initializer="zeros")
        super().build(input_shape)

    def call(self, x):
        e = tf.keras.backend.tanh(tf.keras.backend.dot(x, self.W) + self.b)
        a = tf.keras.backend.softmax(e, axis=1)
        output = x * a
        return tf.keras.backend.sum(output, axis=1)

# ========== MODEL ==========
def build_cnn_lstm_attention(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.3)(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.3)(x)
    x = Reshape((x.shape[1], x.shape[2] * x.shape[3]))(x)
    x = LSTM(128, return_sequences=True)(x)
    x = Dropout(0.3)(x)
    x = AttentionLayer()(x)
    output = Dense(num_classes, activation='softmax')(x)
    return Model(inputs, output)

# ========== UNIVERSAL RUNNER FUNCTION ==========
def run_cnn_lstm_attention(optimizer_name="Adam", lr=0.001, epochs=60, patience=5, batch_size=16, split_ratio=(0.8, 0.1, 0.1), model_save_path="best_model1.keras"):
    X_train, X_val, X_test, y_train, y_val, y_test = split_data(split_ratio=split_ratio)
    
    model = build_cnn_lstm_attention(X_train.shape[1:], num_classes=NUM_CLASSES)

    if optimizer_name == "Adam":
        optimizer = Adam(learning_rate=lr)
    elif optimizer_name == "SGD":
        optimizer = SGD(learning_rate=lr)
    elif optimizer_name == "RMSprop":
        optimizer = RMSprop(learning_rate=lr)
    elif optimizer_name == "Adamax":
        optimizer = Adamax(learning_rate=lr)
    else:
        raise ValueError(f"Unsupported optimizer: {optimizer_name}")

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    checkpoint = ModelCheckpoint(model_save_path, monitor='val_accuracy', save_best_only=True, verbose=1)
    early_stop = EarlyStopping(monitor='val_accuracy', patience=patience, restore_best_weights=True)

    history = model.fit(X_train, y_train, validation_data=(X_val, y_val),
                        epochs=epochs, batch_size=batch_size,
                        callbacks=[early_stop, checkpoint], verbose=1)

    # Load best model from file
    best_model1 = tf.keras.models.load_model(model_save_path, custom_objects={"AttentionLayer": AttentionLayer})

    train_loss, train_acc = best_model1.evaluate(X_train, y_train, verbose=0)
    val_loss, val_acc = best_model1.evaluate(X_val, y_val, verbose=0)
    test_loss, test_acc = best_model1.evaluate(X_test, y_test, verbose=0)

    print(f"\n🧪 Final Training Accuracy: {train_acc * 100:.2f}%")
    print(f"🧪 Final Validation Accuracy: {val_acc * 100:.2f}%")
    print(f"✅ Final Test Accuracy: {test_acc * 100:.2f}%")

    y_pred = best_model1.predict(X_test).argmax(axis=1)
    y_true = y_test.argmax(axis=1)

    print("\n📊 Classification Report:")
    print(classification_report(y_true, y_pred, target_names=class_names))

    cm = confusion_matrix(y_true, y_pred)
    ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names).plot(cmap='Blues')
    plt.title("Confusion Matrix")
    plt.grid(False)
    plt.show()

    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Training vs Validation Accuracy')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training vs Validation Loss')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # ✅ Save model in real .keras zip format (not HDF5)
    model.save("best_model1.keras", save_format="keras")
    print("✅ Model saved successfully in .keras format.")

    return train_acc, val_acc, test_acc

# ========== EXECUTE ==========
print("\n==========================")
print("🔬 Running: CNN-LSTM | RMSprop | 0.001 | 60 Epochs | Split 80:10:10")
print("==========================")
run_cnn_lstm_attention(
    optimizer_name="RMSprop",
    lr=0.001,
    epochs=60,
    batch_size=32,
    patience=10,
    split_ratio=(0.8, 0.10, 0.10)
)
# Out:
# ==========================
# 🔬 Running: CNN-LSTM | RMSprop | 0.001 | 60 Epochs | Split 80:10:10
# ==========================
# Epoch 1/60
# 397/397 [==============================] - ETA: 0s - loss: 1.6053 - accuracy: 0.2221
# Epoch 1: val_accuracy improved from -inf to 0.27078, saving model to best_model1.keras
# 397/397 [==============================] - 306s 753ms/step - loss: 1.6053 - accuracy: 0.2221 - val_loss: 1.5820 - val_accuracy: 0.2708
# Epoch 2/60
# 397/397 [==============================] - ETA: 0s - loss: 1.5439 - accuracy: 0.2953
# Epoch 2: val_accuracy improved from 0.27078 to 0.33438, saving model to best_model1.keras
# 397/397 [==============================] - 306s 770ms/step - loss: 1.5439 - accuracy: 0.2953 - val_loss: 1.4641 - val_accuracy: 0.3344
# Epoch 3/60
# 397/397 [==============================] - ETA: 0s - loss: 1.4401 - accuracy: 0.3544
# Epoch 3: val_accuracy improved from 0.33438 to 0.39169, saving model to best_model1.keras
# 397/397 [==============================] - 270s 681ms/step - loss: 1.4401 - accuracy: 0.3544 - val_loss: 1.3697 - val_accuracy: 0.3917
# Epoch 4/60
# 397/397 [==============================] - ETA: 0s - loss: 1.3373 - accuracy: 0.4167
# Epoch 4: val_accuracy improved from 0.39169 to 0.45277, saving model to best_model1.keras
# 397/397 [==============================] - 273s 688ms/step - loss: 1.3373 - accuracy: 0.4167 - val_loss: 1.2621 - val_accuracy: 0.4528
# Epoch 5/60
# 397/397 [==============================] - ETA: 0s - loss: 1.2030 - accuracy: 0.4868
# Epoch 5: val_accuracy improved from 0.45277 to 0.50189, saving model to best_model1.keras
# 397/397 [==============================] - 282s 711ms/step - loss: 1.2030 - accuracy: 0.4868 - val_loss: 1.1939 - val_accuracy: 0.5019
# Epoch 6/60
# 397/397 [==============================] - ETA: 0s - loss: 1.0560 - accuracy: 0.5612
# Epoch 6: val_accuracy improved from 0.50189 to 0.55730, saving model to best_model1.keras
# 397/397 [==============================] - 286s 720ms/step - loss: 1.0560 - accuracy: 0.5612 - val_loss: 1.0678 - val_accuracy: 0.5573
# Epoch 7/60
# 397/397 [==============================] - ETA: 0s - loss: 0.9034 - accuracy: 0.6243
# Epoch 7: val_accuracy improved from 0.55730 to 0.61776, saving model to best_model1.keras
# 397/397 [==============================] - 279s 703ms/step - loss: 0.9034 - accuracy: 0.6243 - val_loss: 0.9046 - val_accuracy: 0.6178
# Epoch 8/60
# 397/397 [==============================] - ETA: 0s - loss: 0.8059 - accuracy: 0.6677
# Epoch 8: val_accuracy improved from 0.61776 to 0.64736, saving model to best_model1.keras
# 397/397 [==============================] - 279s 703ms/step - loss: 0.8059 - accuracy: 0.6677 - val_loss: 0.7984 - val_accuracy: 0.6474
# Epoch 9/60
# 397/397 [==============================] - ETA: 0s - loss: 0.7154 - accuracy: 0.6989
# Epoch 9: val_accuracy improved from 0.64736 to 0.68892, saving model to best_model1.keras
# 397/397 [==============================] - 287s 724ms/step - loss: 0.7154 - accuracy: 0.6989 - val_loss: 0.7188 - val_accuracy: 0.6889
# Epoch 10/60
# 397/397 [==============================] - ETA: 0s - loss: 0.6615 - accuracy: 0.7238
# Epoch 10: val_accuracy improved from 0.68892 to 0.70781, saving model to best_model1.keras
# 397/397 [==============================] - 299s 753ms/step - loss: 0.6615 - accuracy: 0.7238 - val_loss: 0.7222 - val_accuracy: 0.7078
# Epoch 11/60
# 397/397 [==============================] - ETA: 0s - loss: 0.6201 - accuracy: 0.7409
# Epoch 11: val_accuracy improved from 0.70781 to 0.71033, saving model to best_model1.keras
# 397/397 [==============================] - 292s 737ms/step - loss: 0.6201 - accuracy: 0.7409 - val_loss: 0.6714 - val_accuracy: 0.7103
# Epoch 12/60
# 397/397 [==============================] - ETA: 0s - loss: 0.5823 - accuracy: 0.7507
# Epoch 12: val_accuracy improved from 0.71033 to 0.71411, saving model to best_model1.keras
# 397/397 [==============================] - 280s 705ms/step - loss: 0.5823 - accuracy: 0.7507 - val_loss: 0.6426 - val_accuracy: 0.7141
# Epoch 13/60
# 397/397 [==============================] - ETA: 0s - loss: 0.5585 - accuracy: 0.7567
# Epoch 13: val_accuracy improved from 0.71411 to 0.72607, saving model to best_model1.keras
# 397/397 [==============================] - 287s 722ms/step - loss: 0.5585 - accuracy: 0.7567 - val_loss: 0.6179 - val_accuracy: 0.7261
# Epoch 14/60
# 397/397 [==============================] - ETA: 0s - loss: 0.5326 - accuracy: 0.7625
# Epoch 14: val_accuracy improved from 0.72607 to 0.73615, saving model to best_model1.keras
# 397/397 [==============================] - 287s 722ms/step - loss: 0.5326 - accuracy: 0.7625 - val_loss: 0.6235 - val_accuracy: 0.7361
# Epoch 15/60
# 397/397 [==============================] - ETA: 0s - loss: 0.5198 - accuracy: 0.7708
# Epoch 15: val_accuracy did not improve from 0.73615
# 397/397 [==============================] - 286s 721ms/step - loss: 0.5198 - accuracy: 0.7708 - val_loss: 0.6764 - val_accuracy: 0.7248
# Epoch 16/60
# 397/397 [==============================] - ETA: 0s - loss: 0.5116 - accuracy: 0.7739
# Epoch 16: val_accuracy did not improve from 0.73615
# 397/397 [==============================] - 283s 713ms/step - loss: 0.5116 - accuracy: 0.7739 - val_loss: 0.6458 - val_accuracy: 0.7280
# Epoch 17/60
# 397/397 [==============================] - ETA: 0s - loss: 0.5004 - accuracy: 0.7748
# Epoch 17: val_accuracy did not improve from 0.73615
# 397/397 [==============================] - 282s 710ms/step - loss: 0.5004 - accuracy: 0.7748 - val_loss: 0.6513 - val_accuracy: 0.7292
# Epoch 18/60
# 397/397 [==============================] - ETA: 0s - loss: 0.4882 - accuracy: 0.7829
# Epoch 18: val_accuracy did not improve from 0.73615
# 397/397 [==============================] - 273s 687ms/step - loss: 0.4882 - accuracy: 0.7829 - val_loss: 0.6194 - val_accuracy: 0.7305
# Epoch 19/60
# 397/397 [==============================] - ETA: 0s - loss: 0.4783 - accuracy: 0.7863
# Epoch 19: val_accuracy improved from 0.73615 to 0.74937, saving model to best_model1.keras
# 397/397 [==============================] - 273s 687ms/step - loss: 0.4783 - accuracy: 0.7863 - val_loss: 0.6217 - val_accuracy: 0.7494
# Epoch 20/60
# 397/397 [==============================] - ETA: 0s - loss: 0.4811 - accuracy: 0.7846
# Epoch 20: val_accuracy did not improve from 0.74937
# 397/397 [==============================] - 282s 711ms/step - loss: 0.4811 - accuracy: 0.7846 - val_loss: 0.6558 - val_accuracy: 0.7330
# Epoch 21/60
# 397/397 [==============================] - ETA: 0s - loss: 0.4731 - accuracy: 0.7867
# Epoch 21: val_accuracy did not improve from 0.74937
# 397/397 [==============================] - 280s 706ms/step - loss: 0.4731 - accuracy: 0.7867 - val_loss: 0.6301 - val_accuracy: 0.7349
# Epoch 22/60
# 397/397 [==============================] - ETA: 0s - loss: 0.4659 - accuracy: 0.7910
# Epoch 22: val_accuracy improved from 0.74937 to 0.75441, saving model to best_model1.keras
# 397/397 [==============================] - 263s 661ms/step - loss: 0.4659 - accuracy: 0.7910 - val_loss: 0.6115 - val_accuracy: 0.7544
# Epoch 23/60
# 397/397 [==============================] - ETA: 0s - loss: 0.4612 - accuracy: 0.7916
# Epoch 23: val_accuracy did not improve from 0.75441
# 397/397 [==============================] - 258s 651ms/step - loss: 0.4612 - accuracy: 0.7916 - val_loss: 0.6387 - val_accuracy: 0.7374
# Epoch 24/60
# 397/397 [==============================] - ETA: 0s - loss: 0.4580 - accuracy: 0.7909
# Epoch 24: val_accuracy improved from 0.75441 to 0.76008, saving model to best_model1.keras
# 397/397 [==============================] - 259s 652ms/step - loss: 0.4580 - accuracy: 0.7909 - val_loss: 0.6499 - val_accuracy: 0.7601
# Epoch 25/60
# 397/397 [==============================] - ETA: 0s - loss: 0.4500 - accuracy: 0.7984
# Epoch 25: val_accuracy did not improve from 0.76008
# 397/397 [==============================] - 257s 648ms/step - loss: 0.4500 - accuracy: 0.7984 - val_loss: 0.7186 - val_accuracy: 0.7513
# Epoch 26/60
# 397/397 [==============================] - ETA: 0s - loss: 0.4479 - accuracy: 0.7965
# Epoch 26: val_accuracy did not improve from 0.76008
# 397/397 [==============================] - 259s 651ms/step - loss: 0.4479 - accuracy: 0.7965 - val_loss: 0.6931 - val_accuracy: 0.7487
# Epoch 27/60
# 397/397 [==============================] - ETA: 0s - loss: 0.4427 - accuracy: 0.7968
# Epoch 27: val_accuracy did not improve from 0.76008
# 397/397 [==============================] - 262s 660ms/step - loss: 0.4427 - accuracy: 0.7968 - val_loss: 0.6527 - val_accuracy: 0.7424
# Epoch 28/60
# 397/397 [==============================] - ETA: 0s - loss: 0.4387 - accuracy: 0.7997
# Epoch 28: val_accuracy did not improve from 0.76008
# 397/397 [==============================] - 264s 665ms/step - loss: 0.4387 - accuracy: 0.7997 - val_loss: 0.6806 - val_accuracy: 0.7557
# Epoch 29/60
# 397/397 [==============================] - ETA: 0s - loss: 0.4361 - accuracy: 0.8024
# Epoch 29: val_accuracy did not improve from 0.76008
# 397/397 [==============================] - 259s 652ms/step - loss: 0.4361 - accuracy: 0.8024 - val_loss: 0.6944 - val_accuracy: 0.7494
# Epoch 30/60
# 397/397 [==============================] - ETA: 0s - loss: 0.4340 - accuracy: 0.7986
# Epoch 30: val_accuracy did not improve from 0.76008
# 397/397 [==============================] - 263s 662ms/step - loss: 0.4340 - accuracy: 0.7986 - val_loss: 0.7161 - val_accuracy: 0.7576
# Epoch 31/60
# 397/397 [==============================] - ETA: 0s - loss: 0.4320 - accuracy: 0.7972
# Epoch 31: val_accuracy did not improve from 0.76008
# 397/397 [==============================] - 268s 675ms/step - loss: 0.4320 - accuracy: 0.7972 - val_loss: 0.7359 - val_accuracy: 0.7525
# Epoch 32/60
# 397/397 [==============================] - ETA: 0s - loss: 0.4294 - accuracy: 0.8009
# Epoch 32: val_accuracy did not improve from 0.76008
# 397/397 [==============================] - 261s 658ms/step - loss: 0.4294 - accuracy: 0.8009 - val_loss: 0.7272 - val_accuracy: 0.7424
# Epoch 33/60
# 397/397 [==============================] - ETA: 0s - loss: 0.4245 - accuracy: 0.8035
# Epoch 33: val_accuracy did not improve from 0.76008
# 397/397 [==============================] - 262s 660ms/step - loss: 0.4245 - accuracy: 0.8035 - val_loss: 0.7443 - val_accuracy: 0.7399
# Epoch 34/60
# 397/397 [==============================] - ETA: 0s - loss: 0.4265 - accuracy: 0.8016
# Epoch 34: val_accuracy did not improve from 0.76008
# 397/397 [==============================] - 265s 668ms/step - loss: 0.4265 - accuracy: 0.8016 - val_loss: 0.6650 - val_accuracy: 0.7513
#
# 🧪 Final Training Accuracy: 81.78%
# 🧪 Final Validation Accuracy: 76.01%
# ✅ Final Test Accuracy: 75.88%
# 50/50 [==============================] - 9s 154ms/step
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#   belly pain       0.86      0.93      0.89       318
#      burping       0.83      0.91      0.87       317
#   discomfort       0.70      0.88      0.78       318
#       hungry       0.55      0.21      0.30       318
#        tired       0.73      0.86      0.79       317
#
#     accuracy                           0.76      1588
#    macro avg       0.73      0.76      0.73      1588
# weighted avg       0.73      0.76      0.73      1588
# ✅ Model saved successfully in .keras format.
# (0.8177739381790161, 0.760075569152832, 0.758816123008728)

# %%
import sys, tensorflow as tf

print(f"Python: {sys.version}")
print(f"TensorFlow: {tf.__version__}")
print(f"Keras: {tf.keras.__version__}")
print("GPU Available:", tf.config.list_physical_devices('GPU'))
# Out:
# Python: 3.11.7 | packaged by Anaconda, Inc. | (main, Dec 15 2023, 18:05:47) [MSC v.1916 64 bit (AMD64)]
# TensorFlow: 2.12.0
# Keras: 2.12.0
# GPU Available: []

# %%
model.save('best_model.h5', save_format='h5')  # HDF5 format is more stable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model.save('best_model.h5', save_format='h5')
#
# NameError: name 'model' is not defined
